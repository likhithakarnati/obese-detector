# %% [markdown]
# <a href="https://colab.research.google.com/github/likhithakarnati/obese-detector/blob/main/onionprice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
raw_df = pd.read_html('https://raw.githubusercontent.com/diazoniclabs/Microland/main/onion_2019.html')
df=raw_df[-1]
df
# Out:
#             Date     Market  Arrival(q) Price Minimum (Rs/q)  \
# 0    01/Jan/2019  BANGALORE       17819                  600
# 1    02/Jan/2019  BANGALORE       16948                  600
# 2    03/Jan/2019  BANGALORE       21184                  600
# 3    04/Jan/2019  BANGALORE       21184                  600
# 4    05/Jan/2019  BANGALORE       22709                  600
# ..           ...        ...         ...                  ...
# 936  27/Dec/2019    KOLKATA        1920                 8500
# 937  28/Dec/2019    KOLKATA        1760                 8500
# 938  30/Dec/2019    KOLKATA        2560                 7500
# 939  31/Dec/2019    KOLKATA        2720                 6750
# 940          NaN      Total     8522660            2012(Avg)
#
#     Price Maximum (Rs/q) Modal Price (Rs/q)
# 0                   1400                900
# 1                   1400                900
# 2                   1400                900
# 3                   1400                900
# 4                   1400                900
# ..                   ...                ...
# 936                 9000               8750
# 937                 9250               8875
# 938                 8750               8125
# 939                 7500               7125
# 940            2977(Avg)          2521(Avg)
#
# [941 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941 entries, 0 to 940
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  940 non-null    object
#  1   Market                941 non-null    object
#  2   Arrival(q)            941 non-null    int64
#  3   Price Minimum (Rs/q)  941 non-null    object
#  4   Price Maximum (Rs/q)  941 non-null    object
#  5   Modal Price (Rs/q)    941 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 44.2+ KB

# %%
df = df.dropna()
df
# Out:
#             Date     Market  Arrival(q) Price Minimum (Rs/q)  \
# 0    01/Jan/2019  BANGALORE       17819                  600
# 1    02/Jan/2019  BANGALORE       16948                  600
# 2    03/Jan/2019  BANGALORE       21184                  600
# 3    04/Jan/2019  BANGALORE       21184                  600
# 4    05/Jan/2019  BANGALORE       22709                  600
# ..           ...        ...         ...                  ...
# 935  26/Dec/2019    KOLKATA        1920                 8500
# 936  27/Dec/2019    KOLKATA        1920                 8500
# 937  28/Dec/2019    KOLKATA        1760                 8500
# 938  30/Dec/2019    KOLKATA        2560                 7500
# 939  31/Dec/2019    KOLKATA        2720                 6750
#
#     Price Maximum (Rs/q) Modal Price (Rs/q)
# 0                   1400                900
# 1                   1400                900
# 2                   1400                900
# 3                   1400                900
# 4                   1400                900
# ..                   ...                ...
# 935                 9000               8750
# 936                 9000               8750
# 937                 9250               8875
# 938                 8750               8125
# 939                 7500               7125
#
# [940 rows x 6 columns]

# %%
pd.to_datetime(df['Date'])
# Out:
# 0     2019-01-01
# 1     2019-01-02
# 2     2019-01-03
# 3     2019-01-04
# 4     2019-01-05
#          ...
# 935   2019-12-26
# 936   2019-12-27
# 937   2019-12-28
# 938   2019-12-30
# 939   2019-12-31
# Name: Date, Length: 940, dtype: datetime64[ns]

# %%
df['Date']= pd.to_datetime(df['Date'])
# Out:
# <ipython-input-117-fb5ecebf89eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']= pd.to_datetime(df['Date'])

# %% [markdown]
# # Explore the Average value price of Onion in different cities wrt Date
#
# # 1. Rename the column of Average Price
#
# # 2. Consider the column Date and Average Price and drop other columns
#
# # 3. Check the missing/unwanted values and drop them
#
# # 4. Convert the columns into required datatype
#
# # 5. Plot the Line chart for avg value price of different cities
#
# # - Which are the different cities
#
# # - Which city and date pricing is highest/lowest
#
# # - Group the avg price based on city
#
# # - Highest/Lowest Price of onion in every city

# %%
df = df.rename(columns={'Modal Price (Rs/q)':'Avg'})
df
# Out:
#           Date     Market  Arrival(q) Price Minimum (Rs/q)  \
# 0   2019-01-01  BANGALORE       17819                  600
# 1   2019-01-02  BANGALORE       16948                  600
# 2   2019-01-03  BANGALORE       21184                  600
# 3   2019-01-04  BANGALORE       21184                  600
# 4   2019-01-05  BANGALORE       22709                  600
# ..         ...        ...         ...                  ...
# 935 2019-12-26    KOLKATA        1920                 8500
# 936 2019-12-27    KOLKATA        1920                 8500
# 937 2019-12-28    KOLKATA        1760                 8500
# 938 2019-12-30    KOLKATA        2560                 7500
# 939 2019-12-31    KOLKATA        2720                 6750
#
#     Price Maximum (Rs/q)   Avg
# 0                   1400   900
# 1                   1400   900
# 2                   1400   900
# 3                   1400   900
# 4                   1400   900
# ..                   ...   ...
# 935                 9000  8750
# 936                 9000  8750
# 937                 9250  8875
# 938                 8750  8125
# 939                 7500  7125
#
# [940 rows x 6 columns]

# %%
df = df[['Date','Market','Avg']]
df
# Out:
#           Date     Market   Avg
# 0   2019-01-01  BANGALORE   900
# 1   2019-01-02  BANGALORE   900
# 2   2019-01-03  BANGALORE   900
# 3   2019-01-04  BANGALORE   900
# 4   2019-01-05  BANGALORE   900
# ..         ...        ...   ...
# 935 2019-12-26    KOLKATA  8750
# 936 2019-12-27    KOLKATA  8750
# 937 2019-12-28    KOLKATA  8875
# 938 2019-12-30    KOLKATA  8125
# 939 2019-12-31    KOLKATA  7125
#
# [940 rows x 3 columns]

# %%
df['Date']= pd.to_datetime(df['Date'])
df['Avg']= df['Avg'].astype(int)
# Out:
# <ipython-input-120-5b22f3ad5c9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']= pd.to_datetime(df['Date'])
# <ipython-input-120-5b22f3ad5c9d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Avg']= df['Avg'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 940 entries, 0 to 939
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    940 non-null    datetime64[ns]
#  1   Market  940 non-null    object
#  2   Avg     940 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 29.4+ KB

# %%
u = df['Market'].unique()
u
# Out:
# array(['BANGALORE', 'CHENNAI', 'DELHI', 'KOLKATA'], dtype=object)

# %%
df['Market'].value_counts()
# Out:
# DELHI        252
# BANGALORE    246
# CHENNAI      240
# KOLKATA      202
# Name: Market, dtype: int64

# %%
price_max = df['Avg'].max()
price_max
# Out:
# 14000

# %%
df[df['Avg'] == price_max]
# Out:
#           Date     Market    Avg
# 229 2019-12-06  BANGALORE  14000
# 468 2019-12-07    CHENNAI  14000

# %%
price_min = df['Avg'].min()
price_min
# Out:
# 550

# %%
df[df['Avg'] == price_min]
# Out:
#          Date     Market  Avg
# 30 2019-02-11  BANGALORE  550

# %%
df.groupby('Market').mean(numeric_only=True)
# Out:
#                    Avg
# Market
# BANGALORE  2350.463415
# CHENNAI    3062.083333
# DELHI      1831.503968
# KOLKATA    2943.673267

# %%
df.groupby('Market').min(numeric_only=True) #show min of every city
# Out:
#            Avg
# Market
# BANGALORE  550
# CHENNAI    850
# DELHI      585
# KOLKATA    725

# %%
df.groupby('Market').max(numeric_only=True) #show max of every city
# Out:
#              Avg
# Market
# BANGALORE  14000
# CHENNAI    14000
# DELHI       7650
# KOLKATA    11500

# %%
u = df['Market'].unique()
b_df = df[df['Market'] == u[0]]
c_df = df[df['Market'] == u[1]]
d_df = df[df['Market'] == u[2]]
k_df = df[df['Market'] == u[3]]

# %%
import matplotlib.pyplot as plt
plt.plot(b_df['Date'],b_df['Avg'])
plt.plot(c_df['Date'],c_df['Avg'])
plt.plot(d_df['Date'],d_df['Avg'])
plt.plot(k_df['Date'],k_df['Avg'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,3))
plt.plot(b_df['Date'],b_df['Avg'],label=u[0])
plt.plot(c_df['Date'],c_df['Avg'],label=u[1])
plt.plot(d_df['Date'],d_df['Avg'],label=u[2])
plt.plot(k_df['Date'],k_df['Avg'],label=u[3])
plt.legend()
plt.show()

# %%
import prophet

# %%
b_df = b_df.rename(columns = {'Date':'ds','Avg':'y'})
b_df = b_df.drop(columns='Market')
b_df
# Out:
#             ds     y
# 0   2019-01-01   900
# 1   2019-01-02   900
# 2   2019-01-03   900
# 3   2019-01-04   900
# 4   2019-01-05   900
# ..         ...   ...
# 241 2019-12-24  7000
# 242 2019-12-26  7000
# 243 2019-12-27  8250
# 244 2019-12-30  5500
# 245 2019-12-31  5250
#
# [246 rows x 2 columns]

# %%
from prophet import Prophet
m = Prophet()
m.fit(b_df)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkelyhtu6/175cv7w_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkelyhtu6/rk71y3cq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20139', 'data', 'file=/tmp/tmpkelyhtu6/175cv7w_.json', 'init=/tmp/tmpkelyhtu6/rk71y3cq.json', 'output', 'file=/tmp/tmpkelyhtu6/prophet_modela0xuq84_/prophet_model-20230810132642.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:26:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:26:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 603 2020-12-26
# 604 2020-12-27
# 605 2020-12-28
# 606 2020-12-29
# 607 2020-12-30

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 603 2020-12-26  32321.833566  27551.017185  36945.119343
# 604 2020-12-27  32432.070126  27542.440269  36988.013640
# 605 2020-12-28  32246.428921  27304.379127  36978.882936
# 606 2020-12-29  32282.233935  27346.995821  37125.266667
# 607 2020-12-30  32467.951759  27693.343019  37339.303378

# %%
fig1 = m.plot(forecast)
